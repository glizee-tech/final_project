# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace.final_project;

CREATE VOLUME IF NOT EXISTS workspace.final_project.landing;
CREATE VOLUME IF NOT EXISTS workspace.final_project.bronze;
CREATE VOLUME IF NOT EXISTS workspace.final_project.silver;
CREATE VOLUME IF NOT EXISTS workspace.final_project.gold;
